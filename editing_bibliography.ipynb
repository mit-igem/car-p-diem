# %%
def replace_with_quotes(input):
    for i in input:
        if i == "{" or i == "}":
            input = input.replace(i, '"')
    return input

# %%
replace_with_quotes("""author  = "Thomas Siff and Parash Parajuli and Mohammed S. Razzaque and Azeddine Atfi",
  title   = "Cancer-Mediated Muscle Cachexia: Etiology and Clinical Management",
  journal = {Trends in Endocrinology and Metabolism: TEM},
  volume  = {32},
  number  = {6},
  pages   = {382--402},
  year    = {2021},
  doi     = {10.1016/j.tem.2021.03.007},
  url     = {https://doi.org/10.1016/j.tem.2021.03.007}""")
# Out:
# 'author  = "Thomas Siff and Parash Parajuli and Mohammed S. Razzaque and Azeddine Atfi",\n  title   = "Cancer-Mediated Muscle Cachexia: Etiology and Clinical Management",\n  journal = "Trends in Endocrinology and Metabolism: TEM",\n  volume  = "32",\n  number  = "6",\n  pages   = "382--402",\n  year    = "2021",\n  doi     = "10.1016/j.tem.2021.03.007",\n  url     = "https://doi.org/10.1016/j.tem.2021.03.007"'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.array(["Negative Control", 
              "MEGF10 CAR + IL-6::mCherry Lysate",  
              "Fcgamma CAR + IL-6::mCherry Lysate",
              ])
y = np.array([0, 12, 16.2])

plt.figure(figsize=(12, 8), dpi=300,)
plt.bar(x,y)
plt.ylabel("Percentage of CAR-P HEK293 Cells", fontsize=14)
plt.xlabel("Cocultured Samples", fontsize=14)
plt.title("Percentage of CAR-P HEK293 Cells Binding IL-6::mCherry", fontsize=14)

plt.show()
